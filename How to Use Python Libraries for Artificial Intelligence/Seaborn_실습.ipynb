# %% [markdown]
# # Seaborn : 데이터 시각화 라이브러리
# - Matplotlib 기반의 시각화 라이브러리
# - 통계 기반 그래프를 위한 고급 인터페이스 제공
# - 참고 : [공식 홈페이지](https://seaborn.pydata.org/)

# %%
# 설치
# !pip install seaborn

# %%
# 사용
import seaborn as sns

# %% [markdown]
# # 데이터 불러오기
# - seaborn 라이브러리에는 데이터가 내장되어있다
# - **load_dataset()** 함수 이용
# - 참고 : [seaborn 내장 데이터](https://github.com/mwaskom/seaborn-data)

# %%
# titanic 데이터 불러오기
titanic = sns.load_dataset("titanic")

# 데이터 확인
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 데이터의 전반적인 정보 확인
print(titanic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None

# %% [markdown]
# # 선형 회귀선 있는 산점도
# - **regplot()** : 선형 회귀선이 있는 산점도
#   - x축 변수
#   - y축 변수
#   - 데이터 셋
#   - axe 객체
#   - fit_reg : 선형 회귀선 표시 여부
#
# </br>
#
# - **선형 회귀선** : 간단한 선형 데이터 집합에 사용되는 직선 (=추세선)
#   - 데이터를 시간 축으로 봤을 때,
#   - 데이터의 값이 장기적으로 어떻게 변하는지 직선으로 표현한 것

# %%
import matplotlib.pyplot as plt

# %%
# 그래프 객체 생성 (figure에 2개의 서브 플롯 생성)
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

# 산점도에 선형회귀선 표시 (fit_reg = True)
# x축 변수, y축 변수, 데이터 셋, axe 객체(1번째 그래프)
sns.regplot(x='age', y='fare', data=titanic, ax=ax1)

# 산점도에 선형회귀선 미표시 (fit_reg = False)
sns.regplot(x='age', y='fare', data=titanic, ax=ax2, fit_reg=False)

plt.show()

# %% [markdown]
# # 히스토그램과 커널 밀도 그래프
# - **distplot()** : 히스토그램, 커널 밀도 그래프 시각화
#   - 분포를 그릴 데이터 변수
#   - **hist** : True는 히스토그램 표시
#   - **kde** : True는 커널 밀도 그래프 표시
#   - axe 객체
# - **histplot()** : 히스토그램
#   - 하나의 변수 데이터의 분포를 확인할 때 사용
# - **kdeplot()** : 커널 밀도 그래프
#   - 그래프와 x축 사이의 면적이 1이 되도록 그리는 밀도 함수

# %%
# 그래프 객체 생성 (figure에 3개의 서브플롯 생성)
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

# distplot()
# 히스토그램과 커널 밀도 그래프 그리기
# 분포를 그릴 데이터 변수, axe 객에(1번째 그래프)
sns.distplot(titanic['fare'], ax=ax1)

# histplot()
# 분포를 그릴 데이터 변수, 커널밀도그래프 표시안함, axe 객체(2번째 그래프)
# sns.histplot(titanic['fare'], kde=False, ax=ax2)
sns.histplot(x='fare', data=titanic, ax=ax2)

# kdeplot()
# 분포를 그릴 데이터 변수, 히스토그램 표시안함, axe 객체(3번째 그래프)
# sns.kdeplot(titanic['fare'], hist=False, ax=ax3)
sns.kdeplot(x='fare', data=titanic, ax=ax3)

# 차트 제목 표시
# set_title()
ax1.set_title('Titanic fare : distplot')
ax2.set_title("Titanic fare : histplot")
ax3.set_title("Titanic fare : kdeplot")

plt.show()
# Out:
# <ipython-input-13-2f9a98b94fbe>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'], ax=ax1)

# %% [markdown]
# # 범주형 데이터의 산점도
# - **stripplot()** : 데이터 포인트가 중복되어 범주별 분포를 시각화
#   - x축 변수
#   - y축 변수
#   - 데이터 셋
#   - axe 객체
#   - hue : 특정 열 데이터로 색상을 구분하여 출력
#
# - **swarmplot()** : 데이터의 분산까지 고려하여 데이터 포인트가 서로 중복되지 않도록 시각화
#   - x축 변수
#   - y축 변수
#   - 데이터 셋
#   - axe 객체
#   - hue : 특정 열 데이터로 색상을 구분하여 출력

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# titanic 데이터 불러오기
titanic = sns.load_dataset("titanic")

# %%
# 그래프 객체 생성
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

# 이산형 변수의 분포 - 데이터 분산 미고려
# x축 변수, y축 변수, 데이터 셋, axe객체(1번째 그래프)
sns.stripplot(x='class', y='age', data=titanic, ax=ax1, hue="class")

# 이산형 변수의 분포 - 데이터 분산 고려 (중복 X)
# x축 변수, y축 변수, 데이터 셋, axe객체(2번째 그래프), 성별로 색상 구분
sns.swarmplot(x='class', y='age', data=titanic, ax=ax2, hue='sex')

# 차트 제목 표시
ax1.set_title("Strip Plot")
ax2.set_title("Swarm Plot")

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 12.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 빈도 그래프 #
# - **countplot()** : 각 범주에 속하는 데이터의 개수를 막대 그래프로 시각화
#   - x축 변수
#   - palette
#   - 데이터 셋
#   - axe 객체
#   - hue : 특정 열 데이터로 색상을 구분하여 출력

# %%
plt.show()

# %%
# 그래프 객체 생성(figure에 3개의 서브 플롯 생성)
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

# class별 인원 파악
# x축 변수, 데이터 셋, axe 객체(1번째 그래프)
sns.countplot(x="class", palette="Set1", data=titanic, ax=ax1)

# hue 옵션에 'who' 추가
# x축 변수, 데이터 셋, axe 객체(2번째 그래프)
sns.countplot(x='class', hue='who', palette='Set2', data=titanic, ax=ax2)

# dodge=False 옵션 추가 : 축 방향으로 분리하지 않고 누적 그래프 출력
# x축 변수, 데이터 셋, axe 객체(3번째 그래프)
sns.countplot(x='class', hue='who', palette='Set3', dodge=False, data=titanic, ax=ax3)

# 차트 제목 표시
ax1.set_title("titanic class")
ax2.set_title("titanic class - who")
ax3.set_title("titanic class - who(stacked)")

plt.show()
# Out:
# <ipython-input-10-1999d314c4ab>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="class", palette="Set1", data=titanic, ax=ax1)

# %% [markdown]
# # 조인트 그래프
# - **jointplot()** : 산점도를 기본으로 표시, x-y축에 각 변수에 대한 히스토그램을 동시에 시각화
#   - x축 변수
#   - y축 변수
#   - 데이터 셋
#   - **kind = 'reg'** : 선형 회귀선 추가
#   - **kind = 'hex'** : 육각 산점도 추가
#   - **kind = 'kde'** : 커널 밀집 그래프 추가

# %%
# 조인트 그래프 - 산점도(기본값)
# x축 변수, y축 변수, 데이터 셋
j1 = sns.jointplot(x='fare', y="age", data=titanic)
j1.fig.suptitle("titanic fare - scatter", size=15)

plt.show()

# %%
# 조인트 그래프 - 회귀선(kind = 'reg')
# x축 변수, y축 변수, 데이터 셋
j2 = sns.jointplot(x="fare", y="age", kind="reg", data=titanic)
j2.fig.suptitle("titanic fare - reg", size=15)

plt.show()

# %%
# 조인트 그래프 - 산점도(kind = 'hex')
# x축 변수, y축 변수, 데이터 셋
j3 = sns.jointplot(x='fare', y='age', kind='hex', data=titanic, color='red')
j3.fig.suptitle("titanic fare - hex", size=15)

plt.show()

# %%
# 조인트 그래프 - 커널 밀집(kind = 'kde')
# x축 변수, y축 변수, 데이터 셋
j4 = sns.jointplot(x='fare', y='age', kind='kde', data=titanic)
j4.fig.suptitle("titanic fare - ked")

plt.show()

# %% [markdown]
# # 관계 그래프
# - **pairplot()** : 인자로 전달되는 데이터프레임의 열(변수)을 두 개씩 짝 지을 수 있는 모든 조합에 대해 표현
# - 열은 정수형 또는 실수형
# - 3개의 열이라면, 3행*3열의 크기로 총 9개의 그리드
# - 각 그리드의 두 변수 간 관계를 나타내는 그래프를 하나씩 그림
# - **같은 변수끼리** 짝을 이루는 대각선 방향으로는 **히스토그램** 시각화
# - **서로 다른 변수** 간에는 **산점도** 시각화

# %%
# 관계 그래프
titanic_pair = titanic[['age', 'pclass', 'fare']]
sns.pairplot(titanic_pair)
